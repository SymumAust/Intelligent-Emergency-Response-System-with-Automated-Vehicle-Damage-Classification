# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount('/content/drive')


# !ls '/content/drive/My Drive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '10, Memorandum for Chief Invigilators Fall 2019(Final) Scan copy .gdoc'
#  14-145502_linkedin-color-icon-linkedin-logo-round-png.png
# '147-1477528_twitter-app-icon-png-transparent-background-twitter-logo (1).png'
#  147-1477528_twitter-app-icon-png-transparent-background-twitter-logo.png
#  180104088.pdf
#  190204063
#  190204063.zip
#  190204105
#  190204105_190204114_B2_Final_Project.zip
#  190204105_190204114_eLearn.zip
# '190204105_190204114_Final_Project Report.pdf'
# '190204105 (1).ipynb'
# '190204105 (1).pdf'
# '190204105 (2).pdf'
# '190204105 (3).pdf'
# '190204105 (4).pdf'
# '190204105 (5).pdf'
# '190204105 (6).pdf'
# '190204105 (7).pdf'
# '190204105 (8).pdf'
# '190204105 (9).pdf'
#  190204105_assessment2.pdf
# '190204105_Assignment1_B2 (1).zip'
#  190204105_Assignment1_B2.zip
# '190204105_Assignment2_B2.zip (Unzipped Files)'
# ...

# %%
DATA_DIR = '/content/drive/My Drive/Accident-and-Damage-Detection-Identifying-and-Categorizing-Involved-Vehicles/dataset/'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data=DATA_DIR, epochs=50, imgsz=64)  # train the model
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/drive/My Drive/Accident-and-Damage-Detection-Identifying-and-Categorizing-Involved-Vehicles'

# %%
from ultralytics import YOLO
import numpy as np


model = YOLO('./runs/classify/train/weights/best.pt')  # load a custom model


results = model('/content/drive/My Drive/Accident-and-Damage-Detection-Identifying-and-Categorizing-Involved-Vehicles/img_accident.jpg')  # predict on an image



names_dict = results[0].names

probs = results[0].probs.data.tolist()

print(names_dict)
print(probs)

print(names_dict[np.argmax(probs)])

if names_dict[np.argmax(probs)] == 'severe':
    print('Chances of occurring fatality very high. Sending the information.....')
elif names_dict[np.argmax(probs)] == 'moderate':
    print('Chances of occurring fatality is quite possible, taking initiative.....')
elif names_dict[np.argmax(probs)] == 'minor':
    print('Chance are very low. take your own step')
# Out:
# image 1/1 /content/drive/My Drive/Accident-and-Damage-Detection-Identifying-and-Categorizing-Involved-Vehicles/img_accident.jpg: 64x64 severe 0.90, moderate 0.07, minor 0.03, 9.8ms
# Speed: 16.2ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# {0: 'minor', 1: 'moderate', 2: 'severe'}
# [0.030939526855945587, 0.06841214746236801, 0.9006483554840088]
# severe
# Chances of occurring fatality very high. Sending the information.....

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


results_path = './runs/classify/train2/results.csv'

results = pd.read_csv(results_path)

plt.figure()
plt.plot(results['                  epoch'], results['             train/loss'], label='train loss')
plt.plot(results['                  epoch'], results['               val/loss'], label='val loss', c='red')
plt.grid()
plt.title('Loss vs epochs')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()


plt.figure()
plt.plot(results['                  epoch'], results['  metrics/accuracy_top1'] * 100)
plt.grid()
plt.title('Validation accuracy vs epochs')
plt.ylabel('accuracy (%)')
plt.xlabel('epochs')

plt.show()
